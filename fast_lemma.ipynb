# %% [markdown]
# # Load libraries

# %%
import tqdm
import re
import nltk

import pandas as pd

from functools import lru_cache
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from scipy.stats import mode

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

# %%
# Create a list of unique stop words
stop_words = set(stopwords.words('english'))

# %%
# Load file from https://www.kaggle.com/datasets/kazanova/sentiment140
data = pd.read_csv("path_to_file_from_link_above", header=None, usecols=[0, 5], names=['target', 'text'])
data
# Out:
#          target                                               text
# 0             0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1             0  is upset that he can't update his Facebook by ...
# 2             0  @Kenichan I dived many times for the ball. Man...
# 3             0    my whole body feels itchy and like its on fire
# 4             0  @nationwideclass no, it's not behaving at all....
# ...         ...                                                ...
# 1599995       4  Just woke up. Having no school is the best fee...
# 1599996       4  TheWDB.com - Very cool to hear old Walt interv...
# 1599997       4  Are you ready for your MoJo Makeover? Ask me f...
# 1599998       4  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999       4  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1600000 rows x 2 columns]

# %%
# Removing garbage from tweets
only_char = lambda x: " ".join(re.sub(r"[^a-zA-Z']", " ", x).split()).lower()
data['text'] = data['text'].apply(only_char)
print(data['text'].head(10))
# Out:
# 0    switchfoot http twitpic com y zl awww that's a...
# 1    is upset that he can't update his facebook by ...
# 2    kenichan i dived many times for the ball manag...
# 3       my whole body feels itchy and like its on fire
# 4    nationwideclass no it's not behaving at all i'...
# 5                          kwesidei not the whole crew
# 6                                           need a hug
# 7    loltrish hey long time no see yes rains a bit ...
# 8                   tatiana k nope they didn't have it
# 9                                twittera que me muera
# Name: text, dtype: object

# %%
# In this case, we select the token of the part of speech as the most common for the current word
def safe_get_pos(token):
    pos_synset_list = list()
    synsets = wordnet.synsets(token)
    for synset in synsets:
        pos_synset_list.append(synset.pos())
    return mode(pos_synset_list)[0][0] if len(synsets) > 0 else wordnet.NOUN

# %%
# Initialize the lemmatizer object
lemmatizer = WordNetLemmatizer()

# %%
# We will cache the results of the lemmatization function for each unique word.
@lru_cache(maxsize=None)
def cached_lemmatize(token):
    return lemmatizer.lemmatize(token, pos=safe_get_pos(token))

# %%
# We use the function from the article with a little modification in line 9
def checkExecTimeMystemOneText(texts):
    lol = lambda lst, sz: [lst[i:i+sz] for i in range(0, len(lst), sz)]
    txtpart = lol(texts, 10000)
    res = []
    for txtp in tqdm.tqdm(txtpart):
        alltexts = ' '.join([txt + ' brborderlinebr ' for txt in txtp])
        tokens = word_tokenize(alltexts)
        words = [cached_lemmatize(token) for token in tokens if token not in stop_words]
        doc = []
        for txt in words:
            if txt != '\n' and txt.strip() != '':
                if txt == 'brborderlinebr':
                    doc = " ".join(doc)
                    res.append(doc)
                    doc = []
                else:
                    doc.append(txt)
    return res
res = checkExecTimeMystemOneText(data['text'])
res
# Out:
#   0%|          | 0/160 [00:00<?, ?it/s]
# 100%|██████████| 160/160 [02:03<00:00,  1.30it/s]
# ["switchfoot http twitpic com zl awww 's bummer shoulda get david carr third day",
#  "upset ca n't update facebook texting might cry result school today also blah",
#  'kenichan dive many time ball manage save rest go bound',
#  'whole body feel itchy like fire',
#  "nationwideclass 's behave 'm mad ca n't see",
#  'kwesidei whole crew',
#  'need hug',
#  "loltrish hey long time see yes rain bit bit lol 'm fine thanks 's",
#  "tatiana k nope n't",
#  'twittera que muera',
#  "spring break plain city 's snow",
#  'pierce ear',
#  "caregiving could n't bear watch think ua loss embarrassing",
#  'octolinz count idk either never talk anymore',
#  "smarrison would 've first n't gun really though zac snyder 's doucheclown",
#  'iamjazzyfizzle wish get watch miss iamlilnicki premiere',
#  "hollis ' death scene hurt severely watch film wry director cut",
#  'file tax',
#  'lettya ahh ive always want see rent love soundtrack',
#  'fakerpattypattz oh dear drink forget table drink',
#  "alydesigns day n't get much do",
#  "one friend call ask meet mid valley today 've time sigh",
#  'angry barista bake cake ated',
#  'week go hop',
#  'blagh class tomorrow',
#  'hate call wake people',
#  'go cry sleep watch marley',
#  'im sad miss lilly',
#  "ooooh lol leslie ok wo n't leslie wo n't get mad",
#  'meh almost lover exception track get depress every time',
#  'hack account aim make new one',
#  'alielayus want go promote gear groove unfornately ride may b go one anaheim may though',
#  'think sleeping option tomorrow realize evaluation morning work afternoon',
#  'julieebaby awe love miss',
#  'humpninja cry asian eye sleep night',
#  "ok 'm sick spend hour sit shower cause sick stand hold back puke like champ bed",
#  'cocomix ill tell ya story late good day ill workin like three hour',
#  'missxu sorry bed time come gmt http gd fnge',
#  "fleurylis n't either depress n't think even want know kid suitcase",
#  "bed class work gym class another day 's gon na fly miss girlfriend",
#  "really n't feel like get today get study tomorrow practical exam",
#  "'s reason teardrop guitar one enough break heart",
#  "sad sad sad n't know hate feel wan na sleep still ca n't",
#  'jonathanrknight awww soo wish see finally comfortable im sad miss',
#  "fall asleep hear tracy girl 's body find sad heart break family",
#  "viennah yay 'm happy job also mean less time",
#  'check user timeline blackberry look like twanking still happen ppl still probs w bgs uids',
#  "oh man ironing jeancjumbe 's fave top wear meet burn",
#  'strangely sad lilo samro break',
#  "tea oh 'm sorry n't think retweeting",
#  "broadband plan ' massive break promise ' http tinyurl com dcuc via www diigo com tautao still wait broadband",
#  "localtweeps wow ton reply may unfollow see friend ' tweet 're scroll fee lot",
#  'duck chicken take wayyy long hatch',
#  'put vacation photo online yr ago pc crash forget name site',
#  'need hug',
#  'andywana sure po much want dont think trade away company asset sorry andy',
#  'oanhlove hate happen',
#  "sad feel dallas go show get ta say though 'd think show would use music game mmm",
#  'ugh degree tomorrow',
#  'u move think u already sd hmmm random u find glad hear yer well',
#  "batmanyng miss p 's commission wutcha play cop 'blood sand '",
#  'leave parking lot work',
#  'life cool',
#  "sadly though 've never get experience post coitus cigarette never",
#  'nice day bad rain come tomorrow',
#  "starrbby bad wo n't around lose job ca n't even pay phone bill lmao aw shuck",
#  'damm back school tomorrow',
#  "mo job money hell min wage f'n clam hour",
#  'katortiz forever see soon',
#  'lt algonquin agree saw failwhale allllll day today',
#  "jdarter oh haha dude dont really look em unless someone say hey add sorry 'm terrible need pop",
#  "ninjen 'm sure 're right need start work nikster jar least",
#  'really hate people dis band trace clearly ugly',
#  'gym attire today puma singlet adidas short black business sock leather shoe lucky run cute girl',
#  "wo n't show location http twitpic com e",
#  'picnic phone smell like citrus',
#  "ashleyac donkey sensitive comment nevertheless 'd 'd glad see mug asap charger still awol",
#  'new csi tonight fml',
#  'think arm sore tennis',
#  'wonder someone u like much make unhappy split seccond depress',
#  'sleep soon hate say bye see tomorrow night',
#  'statravelau get ur newsletter fare really unbelievable shame already book pay mine',
#  "missin ' boo",
#  'markhardy itm',
#  "damn n't chalk chalkboard useless",
#  "blast getty villa hat 's sore throat day 's get bad",
#  'msdrama hey miss ya meet sup mama',
#  "tummy hurt wonder hypnosis anything 's work get stop smoking",
#  'always fat one',
#  "januarycrimson sorry babe fam annoy thankfully 're asleep right muahaha evil laugh",
#  'hollywoodheat pay attention cover photoshop webpage design class undergrad',
#  "wednesday b day n't know",
#  'poor cameron hill',
#  'pray please ex threaten start sh baby st birthday party jerk still headache',
#  'makeherfamous hmm u really enjoy problem constant u think thing find someone ulike',
#  'strider sick little puppy http apps facebook com dogbook profile view',
#  "rylee grace wana go steve 's party sadly since easter wnt b able much ohh well",
#  "hey actually one bracket pool bad n't one money",
#  "stark n't follow either work",
#  'bad nite favorite team astros spartan lose nite w good',
#  'body miss northern calif girl find police find remain miss northern california girl http tr im imji',
#  'mangaaa hope increase capacity fast yesterday pain get fail whale time hour',
#  'behind class work',
#  'watch quot house quot',
#  'kpreyes remember bum leg strike back time serious',
#  'paradisej cool kind complaint laptop online overheat recall',
#  'emily glad mommy do train new job miss http apps facebook com dogbook profile view',
#  'would rather first party send bad message rd party send mix one sophmore year',
#  "henkuyinepu 's overrate",
#  'marykatherine q know hear afternoon wonder thing moscow behind time',
#  'lay bed voice',
#  "'m sooo sad kill kutner house whyyyyyyyy",
#  'jacobsummers sorry tell mea culpa really sorry',
#  "alliana n't make sense suicide thing refuse believe actually happen",
#  'salancaster hope ok',
#  "mercedesashley damn grind inspirational sadden time n't want stop cuz like u much love",
#  'hibanick yeah aw know wudnt stand chance',
#  'ugh cant sleep',
#  "hang crooner wan na sing ca n't suck",
#  'erre sc aaw miss ya im leave bh tomorrow quot morning quot think aww wan na go beach w u girl',
#  "pissed 's asba 's radio station",
#  "wednesday b day n n't know",
#  'know life flip upside think head ramen sound good',
#  'pain back side hurt mention cry make fail',
#  "late night snack glass oj b c 'm quot sickness quot back sleep ugh hate get sick",
#  "allyheman 'm big fan camilla belle",
#  "grum wah ca n't see clip must el stupido work filter ca n't wait 'till get 'puter something else blame ex break mine",
#  "week seem get long long term much need much 'm actually go get do",
#  "'m cold",
#  "thecoolestout ehhh n't weather 's gon na take turn ugly tomorrow",
#  'chelserlynn haha cooooold still go show incredible stuff',
#  'hop tummy rumble go away soon',
#  "knight notice tell 'd work tomorrow call agency follow say",
#  'almost bedtime',
#  "'m miss babe long alive 'm happy yawwwnn 'm tire love imma try sleep hopefully headstart",
#  'agh snow',
#  'miss kenny power',
#  "bridgetsbeaches thank let people know 'm sad direct message get n't actually bridget",
#  'india miss th test victory n th consecutive win without loss',
#  "jonathanrknight guess 's",
#  'sadly go bed',
#  'ozesteph shame hear stephan',
#  "mrsaintnick hey 'm leavin morning",
#  'intend finish edit page novel manuscript tonight probably happen page leave',
#  'lay around much today head hurt',
#  "twista still n't read th amp th princess diary save francesca make cry end hmm easy book",
#  'nokia die',
#  "mom might breast cancer wo n't find anything like week 'm worry",
#  'go sleep hop tomorrow good day',
#  'rumblepurr lol wish understand daylight save end though breakfast hour late keep wake kid',
#  'onemoreproject lame',
#  "n't understand really n't",
#  "hero n't season",
#  "live downtown sure n't much fun",
#  'jonathanchard calorie wise wish junk food calorie free eat thing sour skittle big as cherry coke',
#  'man work hard',
#  'get sick time hot tea study sleeeep',
#  'get eyebrow wax pain',
#  'phantasy star yesterday go work',
#  "oh get macheist apps sweet n't get espresso serial though although say send oh well",
#  "pick mich st win get go feel pretty good pick way tonight 's lose",
#  'alone downstairs work',
#  'feel bad',
#  "ryanseacrest hat anoop mean seriously 's kinda mean",
#  'pinkserendipity yes sprint g baltimore chicago far',
#  "'m stick awake middle night second day row felt terrible yesterday",
#  'thanks burst bubble',
#  "go school soon ca n't find anything wear gosh 's hard",
#  'marieclr serious lol',
#  'naughtyhaughty page sooooo long get delete sad day history',
#  'crazy wind today bird http ff im xtti',
#  'currently work',
#  "grrr ipod act weird jai ho think n't play full song ughh",
#  'penndbad send dvd co miss heap happy',
#  "n't see big deal website",
#  "machineplay 'm sorry 're go therapyfail",
#  'colindemar far way rail tip',
#  "'m still swear keep lose gain lose gain tweeps heart wrench",
#  "today realize good hide thing even ca n't find",
#  'stay friend house house sit neighbor loud party',
#  'dannyvegasbaby danny im upset wasnt watch live chat car hour trip im soooo upset',
#  'check mug http www erika obscura blogspot com',
#  'border close',
#  "download nin 's new album quot slip quot hell come 'm behind time day",
#  "wake already write e mail 've go early university today teach",
#  'watch hill make sad',
#  'many channel yet boring lazy day may find hobby',
#  'supersport miss buddy ill ny th',
#  "robluketic love french tell people south 'm qtr french snarl french beautiful people",
#  'opps say still get one day remain problem come',
#  "activate selfcontrol block early mean ca n't check new qc regularize internal clock might difficult fb",
#  'hillydop oh',
#  'spencer good guy',
#  'goodlaura reese die ttsc season finale next week boring madame president crazy woman',
#  'jonathanrknight hate limited letter hope guy fine pray dog well',
#  "n't get shit do today 'm screw",
#  'wanttss go',
#  'go sleep tonite',
#  'worry tire post tonight',
#  "could n't get shit do today 'm screw",
#  'job interview cardiff today wish luck get hour sleep',
#  "stustone show whack way bad whack 's wiggety whack",
#  "djalizay really n't think people choose way think choose accept family 's help might dead",
#  "eloquentembrace 're go kill 've see d 've wait till one solid week sit",
#  'cheechbud think ur right hahaha hr',
#  'hate see spartan sad',
#  'mind body severely protest quot get quot thing nightmare boot',
#  "mysteezradio 'm goin ' follow u since u n't lol go angel",
#  'mandayyy',
#  "twista think want read book library n't",
#  "nap interrupt many time today go japanese 'rents",
#  'kind long bus show end ghost world right ugh',
#  "gurumn canada canada weird 're suppose get snow wednesday ugh",
#  "awwh babs look sad underneith shop entrance quot yesterday 's musik quot like look new transformer movie",
#  "sad 'feet ' macbook fell",
#  "'m gon na get late tomorrow 's gon na get tipsy lonesome 's 's sad",
#  "'m sweating forthcoming trip e ca n't find someone crash 'm may screw",
#  'get somebody read tweet cant get make account',
#  'infinitydefines omgawd couldnt handle cat heat time',
#  'donniewahlberg hope make auburn show look good',
#  'david henrie thats people mag haha couldnt fit dont think picture ever make magazine tho haha',
#  'breadandbadger congrats totally forget submit photo',
#  "paulaabdul awww good luck paula please n't work hard hope fun new album gon na amazing xxx",
#  'imaginarypeach leave get sad',
#  "miss twitter phone break 'm use stupid nokia phone ughhh miss advance phone",
#  'shoot outside house kid scar',
#  'tuesday start reflection n lecture stress reduce technique sure might become useful u accompaniers',
#  'tragedy disaster news week',
#  'yes yes still try find picture upload correclty',
#  'oh red sox game rain look forward opening day',
#  "still ca n't find key",
#  'charlietm know right dunno go twitter',
#  'might get sore throat',
#  'labelsnotlove home town mammy call depressd pls explain parent let yr old child walk alone hello',
#  'ircmaxell think need find good anti depressant think paxil wellbutrin combo lose efficacy',
#  'myconnecticut restaurant call woodntap competitive eat tourney round tourney time place nd',
#  'bathroom wake lakin',
#  'caitlinoconnor want taco margarhitas telll gay say hello lt',
#  'im lonely keep company female california',
#  'bad day betfair office',
#  "miss ca n't wait celebrate tar heel win weekend though",
#  "'m really cold n't want go sleep yet 's nothing",
#  "kristencampisi u ' officially ' go round",
#  "monkey find twin wont even write back 'm heartbroken",
#  'miss om aww know felt like yesterday work',
#  "sarahreedsc treaty n't define",
#  'miss brent praise band fun lead guitarist lt pout gt',
#  'jpfurry poor john happen play fruit microwave seriously though see doctor xxx',
#  'miss bff watch home away remind lt shout u court',
#  'mandayyy',
#  'new video card doa',
#  'feel lose naked confuse jk sort iphone',
#  'damn late fill appraisal form people almost send occupy work',
#  'miss brent praise band fun lead guitarist lt pout gt',
#  'think much past cant change deserved much wat get still think gah',
#  "lose ring 's see",
#  'burgaw ooooooh sealclap see download shitloads zip folder chan internet money fuck yeah alicia amp mikey',
#  'still nurse nile glad feel good hate baby sick',
#  'fuck go back ic',
#  "brandizzzle yoyoyo internet rude tonight reconnected 'm go bed",
#  "jemcam well uni stuff netball netbal 've do uni stuff",
#  'kissability poor',
#  'help forget th april amp th july',
#  "dierks bentley comin ' columbus oh wan na go bad",
#  'take sidekick back',
#  "chriscantore congrats 'm totally jealous wish xm work",
#  'gr face itchy',
#  'poor sock luvvvvv golden retriever want one sighhhh',
#  'saw find tracy girl piece luggage fucking terrible',
#  'aaaaand nausea back',
#  'donniewahlberg ooh excite even go long love youtube',
#  'spend hour reach axis bank find today holiday mahavir jayanti contd',
#  'mathewsmichael agree jobros dont update there often',
#  'fishmouse hilarious link clip lj time ago go back dead link',
#  'diannepulham oooooooo im neither thats need study',
#  "n't tweet nearly day post website tonight hopefully go well night time",
#  'bostongarden miss bentley',
#  'seriously need finish job application',
#  'son vinca sick stay home three tense day work back holiday kid',
#  "whinging client amp bos n't understand english well rewrite text unreadable 's write v good writer amp review correctly",
#  "huntermoore n't want ever punch",
#  'sooo sick snow ughh',
#  'nemesis',
#  "lovemeagan n't work fan upset",
#  'would like apologize repeat video game live relate tweet go stern discussion koodo soon stern',
#  'zaydia cant figure get back pay hotel etc',
#  'fml much seniority bc technological ineptness quot register quot class',
#  'feel like sleep day away look forward bout gallbladder least pill pain',
#  'thastevieg really want old bass back',
#  'mad tire today callin early tonight nighty night twittas',
#  'levenrambin take easy good',
#  "'m afraid bad code",
#  "think 'm go bed goodniight hate",
#  "riancurtis 'm friend love",
#  "kariajay time n't notice go need db",
#  'aaronrva bathroom pee',
#  'ashleyskyy want margarita',
#  'kourtneykardash yup night workout r bad unfortunetly work schedule allow go night tough',
#  "call hillsong say could n't tell wait list n't know 's look good",
#  'g milky bar leave around ml coke',
#  "jokerrrr stillllll n't arrive",
#  'mraow feel like dance first art school want rape',
#  "karenucol ah bet 've like crave play softball basketball noo time",
#  'terrified accidentally delete reference management assignment hop doesnt get trouble get back',
#  'amazon plugin work website need php host provider php sad',
#  "argh suuuper sleepy hour ago 'm wide awake hope n't stay night",
#  'austinhill wish sell time let know would love hear',
#  'watch tropic thunder dread tomorrow',
#  "qweendassah 's still miss'n",
#  'chiefdelphi',
#  'http twitpic com wr according bro new puppy poo fight cover poop picture steal',
#  "play game home new bos n't call yet",
#  'su yin huen tweet feel unbearable guilt make staff cry http tinyurl com cw l',
#  'poor joshy sick damn tejanos',
#  "thought sandra cantu 's family difficult sad time",
#  'franzglaus know want let everybody know happen',
#  "michigan n't know sigh shameful",
#  'fill two hour',
#  'alicayaba cuuute hey miss na see girl everyday',
#  'jonathanrknight oh mention quot gooooood moooorniiiiiiing quot germany im back cage good office',
#  'throat close string cheese good idea',
#  'aww sandra cantu find dead suitcase miss child story never seem go good poor family',
#  'wish home underneath cover',
#  'walk home school drain energy',
#  "ridley agree shapeshifting copout excite angela 's ep think week noah awesome tho",
#  'savethestrib dang would do know early out plan',
#  "wish good write 's take long write paper",
#  'course access halo mythic map pack download bad news legendary map pack ugh m',
#  "vene ia yet unfortunately another week 've tell 've little bit busy late project",
#  "thecoolestout ha sun 's already go",
#  "day lot hard day let 's see day go tomorrow",
#  'man crush jake peavy let gayforpeavy',
#  'trishzw megafast trip time day tom wed go tonight want see bad try warn tech fail',
#  'michigan state make sad',
#  'omg mouth much pain wan na sleep untill time take brace',
#  'get annoyed easily today gt gt gt biofuel proposal get annoyed easily today gt gt gt biof http tinyurl com ceprvs',
#  'mizzchievouz hey girl site back girlyvue back even video',
#  "hleyf 'm spend time grandma early tomorrow ca n't leave skittle",
#  'get home watch michigan state get tromped',
#  "oh jew bus two year worth class ' work alot organize gt lt 'm finish tonight 's possible bone ache",
#  "griffmiester exchange laptop n't arrive",
#  "hyperbets hope n't last long feel miserable",
#  'rcompo rachel hang outage neccessary gon na home wekend dumb folk make work im free f sit',
#  'theleaguesf fun amp furious new mantra bay breaker get rambunctious city overreact amp clamp',
#  "amber benson hubby reason think 's important good spot red carpet trek movie premiere sod",
#  "swear matter long 've get never get easy man eye hurt wah",
#  'jeffree star jeffree keep hair one color permanent dye fade within week',
#  "otakusecret reaction whoa n't see come",
#  "still sick feel bit good get new medicine hope feel good night sleep ohh 's suppose snow wtf",
#  'dangerm use think maybe get couple hour sleep hon productive right ur dog tire worry',
#  "maddyva thanks lot learn lot new word n't find look",
#  "wish xblm download gamertag 'hitokyri ' gamertag thing nonsense 'm tire",
#  'new testament test',
#  'scoutbuck ton hay troll ahhhh',
#  'stupid movie watch mirror ugggggh stooopeeed rip',
#  'http twitpic com yi love buck',
#  'last one still do',
#  'homework',
#  "n't understand thing get take away n't enough time unfair want back like baby",
#  "scratch du heif two half cooky tum ca n't take anymore shoog poots",
#  'cococourtney listen sweet first time forever miss much go chi town visit plz',
#  'geez busy afternoon meet email meet email meet pm day still go ah dark',
#  'dang another spring break cool bad work week oh well money phone ttyl everbody',
#  'sara kate im afraid ur reply uni age ago',
#  'feel',
#  'carvin lol emotional as men omg late night eat u break',
#  'nick carter aww nick like hair long cut break heart',
#  'wonder jon lose net',
#  "wow depress thing world lose video 've create matter second fml",
#  'nchokkan http www mycomicshop com search tid say stock',
#  'poohpot lmao im sorry poohpot eat',
#  "chance softbelly mtub n't loud",
#  'time move posterior lose fat articulation creaking run drool swim',
#  'listen nathan cry',
#  "today suck 'm gon na die without chris callum wahhh",
#  'stou site update info exam open course must wait mail notice doc um',
#  "ohsbrat 'm sorry 'm feel kinda yucky go come quick",
#  'love scrappy missin already',
#  "want hear seblefebvre 's song myspace mess",
#  'bad news dad cancer die good news new business start life coach practise holistic weight management',
#  'duchess rebecca man intervention soo sad',
#  "help need new boyfriend 'm stick rut",
#  "feel like complete idiot 'm one n't get shit work help",
#  'saw ad craigslist cast call female host g totally psyched realize hoax',
#  "pepperoni roll l call valentino 's say sausage roll pepperoni roll http tinyurl com cec ka",
#  "soillodge yes 's monday",
#  'want new gg episode already',
#  "miss watch rocko 's modern life",
#  'rip sandra sad someone something like',
#  'keep finger cross buddy feel well',
#  "wait eat skinny vega 'm hungry",
#  "marge inovera try tweetdeck hat passion hat 'm sure",
#  "benackerman btw iphone act funny die quickly freeze b 'm admit anything sayin",
#  'sit wonder quot ed quot still strong hold',
#  'bananaface im sorry get sick lol go bed night',
#  'carolrainbow internet home drive ox use internet builder',
#  'steve buscemi weather canada freeze',
#  "twiggassssssss range day 'm back hopefully good",
#  'danadearmond',
#  "anyone read pray grandma 's pain",
#  "wake accident quot 's push 's push quot cry could n't stop wetting pant",
#  'home franklin street almost jump fire someone kick could jenny lose shoe',
#  'johnnybeane hey change default',
#  'finally give bored enough start thing think go problem tho like myspace status',
#  'ellievolia oooonly really lucky eh awh definitely early work',
#  'buttload homework',
#  'need another copy visual studio',
#  "school world week school silly anyway look bright side 'm u",
#  "omg 've economics test dont know thing know omg im gon na fail",
#  'robcthegeek upon time hundred island pride philippine tourism coral clam rare fish poach kinda sad',
#  'henkuyinepu yeah apparently really bad taste',
#  'hummiemd know really surprise since everyone recommend youtube call tomorrow figure',
#  'wait airport ride get harass men try sell ugly hat want sleep',
#  'leave id location go bar fuckkkkkkkkkkkkk',
#  "celycarmo 'm sorry n't understand last comment",
#  'officialrandl announcement stay late last night',
#  'kishorek strange illegal torrent avlbl everywhere legal dvd stock',
#  'enough say imiss u',
#  'trolley pack like sardine padre game remove car good call mt',
#  'randomlynat jeez try help haha',
#  'supamagg happen saturday night along glittery green light',
#  'try reduce number cigarette day',
#  'yea quiet around cuz everyone work im bored death nobody talk',
#  'get ta cook assignment hard',
#  "treesahquiche okay applepears 've talk people 've one ever tell never",
#  "jennifermf know 'm night owl nature hahaha time zone behind 's almost",
#  'mamasvan lol nope complete camerafail',
#  "maxime megelder 'm useless n't sleep 's fair want fun well",
#  'pookie uti nurse gabbie get back soda',
#  'jillianfish tweet something damn hang please',
#  'anistorm',
#  "'m behind video game everything matter 'm yesterday 's news",
#  'sleep til noon one leave get tempt eat soon get home chocolate velvet amp eat mocha',
#  'stress blackberry keep flash red alert status reason fake hate',
#  "http twitpic com e wan na wear doc marten n't wear since december",
#  'shoe repair shop guy could find shoe go back see find couple day',
#  'b barnett really see come',
#  'wake vivid sketchy cool dream life time stare wall light',
#  "'ll take day sister get passport",
#  'nicolerichie oh yes miss',
#  'uh oh think get sick',
#  'good god ruin belly button',
#  'watch frame roger rabbit make miss toon town',
#  'akianz rent cheap rent awesome house buy attempt fall',
#  'run nose spin head good combination meet',
#  'eazydoesit negative lose vote confidence',
#  'nasty budget due iphone send apple today',
#  'sofii noel bad',
#  "dammit episode king wo n't play reason stop middle wo n't anything",
#  "'m upset miss chat quiz online free internet cease",
#  "ca n't believe 'm disbelief way really much take people always get hurt others",
#  'car show season start without',
#  'throat raw',
#  "kevchoice n't get person mind could even ish like prayer fam real",
#  "frago hate n't need see need call therapist",
#  "twilight n't come yesterday finger cross today",
#  'nilelegania glad able help feel good hate see sick love',
#  'tireddddddd want sleep assignment finish exam tomorrow study',
#  'know think need money',
#  'omg jst teusday',
#  'ddlovato david henrie ummmmm cant find',
#  'hear find sandra cantu yr old',
#  'corrosivecandy ive forget snoo snoo wonder snoo snoo ever meet',
#  'amanorris wow last tweet make seem like giant sexist sorry',
#  'bathtub drain fire haz job amp iz fail get drano as amp iz still drain wan na shower dangit',
#  'stick home',
#  'nomadicmatt mine get',
#  "duckling famous child 's book steal boston 's public garden boston globe http tinyurl com dc htx via sharethis oh",
#  'appomattox news thank however hate list include convict',
#  'head altrincham hour install',
#  'morning good im bloody knackered work today helppp xxx',
#  "jeffreecuntstar n't garage park driveway",
#  'lauredhel happen',
#  "quot popular music quot w adorno probably difficult read ever prescribed 'm actually struggle continue",
#  'http twitpic com e cant see flower fall dont camera cellphone',
#  "'ve good 'm like snow right get use nice spring like weather",
#  "brian armstrong pity youtube currently block china ca n't see vids",
#  'margaretcho happen show hightlight life',
#  "best leather sofa world 's office though mean 'm still work",
#  'still day internet get uncapped',
#  "n't get good day could something lodge belly",
#  'love atekinzz much amp amp soo miss',
#  'wan na sneak zoo play kitty',
#  "lolitariot oh hope 're get sick",
#  'alejandralei dont think cause cousin birthday party',
#  'sweet little man fell asleep wait daddy big brother get home poor baby miss much today',
#  'angel go miss athlete weekend',
#  'trust hard',
#  'watch consider today yaknow shawnna tomomorrow need bestfriend',
#  'grr want keep read wont anything leave read',
#  'atekinzz world',
#  'rumlover u suppose date',
#  "pear amp brie bottle cabernet quot win date tad hamilton quot oh gawwd life flash forward 'm cat",
#  'crap need dress',
#  'kaeeeep yeah know horrible ugh sadden',
#  'brodhe geez ur fun',
#  'wan na punk rock band',
#  "jyesmith 's lot angst tuesday afternoon",
#  "'m glad britney n't crazy anymore one hell show 'm sad 's next ap cook county",
#  'huuuge headache omg feel like crap',
#  'anistorm sorry',
#  'cleders sorry root',
#  'man take forever',
#  'shandasaurus see',
#  'list item ebay sell take forever meanwhile coleman watch hill season premier without',
#  "get presentation do slide do 'm cry week hard week",
#  'lose',
#  "n't like previously skin thing start season two like go straight intro like",
#  "houndour wish 'm pretty good scar shit people",
#  'go sound vain run fav lip gloss',
#  "stuiy never click link scream quot 'm spider 'm spider quot know good yucky",
#  'time work get sick',
#  'pratama imac come indonesia state',
#  'dammit need stop buy furniture',
#  'miss sil half asleep turn laptop',
#  'death peaceful life however bite',
#  'think jonathanrknight lose net sure hope',
#  'http gd r zf http gd r zy http gd r zg test footage girlfriend hd dark one underxposed',
#  'tough game watch tonight state finally go bed also stay watch season premiere hill',
#  'seem jruby support hpricot two version behind',
#  "jinxcat unlike sister still n't one",
#  'fraking app store pissing http tinyurl com c ooho',
#  'log need study',
#  'anyone else problem access ttb cant get',
#  'strongly dislike people make stupid comment dont know whole story',
#  "emmaketurah 'm sorry emma swarley goldfish 'm sad u",
#  "tweet already go n't miss guy tonight",
#  "ca n't sleep face kinda swell n't let allergic thing 'll get thursday school tomorrow doubtful",
#  "snick dog izzy 's cat tree 'll stare 's floor chase run",
#  "officially ban godaddy com comp head hurt small print waste could 've happily go boba",
#  'humanopium pretty much scary',
#  "ilovepie mine 'm find well hard get fit",
#  'good morning ready go want go back bed',
#  'hat wait mail',
#  "wheat bread dollar store n't toast nicely go tax call early night",
#  "kutner mean know something go happen someone sad lt house well do 'm still sad",
#  'jonathanrknight aw ok goonite',
#  'ill cant go cinema',
#  "fell asleep really n't mean christina",
#  'kelleyrowe hey remember time use friend ugh vomit sick need sleep',
#  "lymph node massive rahm emanuel 's ball right",
#  "oh computer suck n't think 'll able listen xbox fancast tonite",
#  'miss play trumpet',
#  'throat still really sore mean go day camp friday sure',
#  'sasii know exactly feel',
#  'work',
#  'well bed time sigh back morning week wednesday',
#  'hert jesus camp yeah',
#  'marybethune oh everything happen today forget go dress shop opera tomorrow',
#  'turtle good mac last long move fast',
#  'soak pleasant',
#  'ginayates sorry hear maggie thought mum',
#  'ewarden may email one hope feel good',
#  'miamiiboii dead yu gettin wen im leavin',
#  "arlenecd please tell 's somewhere close california lol",
#  'phlaimeaux',
#  "stupid arrange marriage 'll convert marry love",
#  'emilyruppe well say loose show imply',
#  'poor sandra cantu amp cantu family prayer go sick world live',
#  'fuck omg austin always though man lt love',
#  'nicolerichie cry hard matthew die',
#  "sad 'feet ' macbook fell sad 'feet ' macbook fell",
#  "chordsy last find thing like 're twitter",
#  'lovebscott absolutely',
#  'http twitpic com cf fill curry true indian come',
#  'im soooo cold right',
#  'heidimontag lol kant believe cam get beat upp sooo embarasssiiiin',
#  'jonathanrknight good knight hun look forward ur tweet hate keep miss fun cuz time difference',
#  'tumblr exactly feel wear tie http tinyurl com c bvqh',
#  "daniela hahaa realize quot impune quot definitely isnt word want dang 'm unclever",
#  'watch old video dance team make miss',
#  "wahh csi anywhere dvr'ed love money though gon na watch sleep goodnight tweeter lt",
#  'struggle hard inventory',
#  "ddlovato hate u please n't",
#  'ballinbitch haha im ballin still get bill paaaaay',
#  "'m one day really want work home crap",
#  "paul e wog wait game episode 'm confuse",
#  'carlyw haha cry guess',
#  "n't get statistic bunch mumbo jumbo",
#  'sloanb get sadly work uk amp u moment',
#  'evict',
#  "n't enjoy learn cs",
#  "nachojohnny brian n't make fuck u lol reply ur message u get miss u",
#  "heidimontag dvr 'd go watch apparently dish network go miss catch rerun",
#  'jessdubb lmao u may wait another season come thru summe boo hot nd dry as weather',
#  "lizchavez ca n't set foot grind miss eyelid people might get",
#  'daniela english professor would ashamed',
#  "wish frog n't become extinct http tinyurl com cxe w",
#  'come home cross county tire',
#  "n't want walk home snow want pick",
#  'heidimontag lauren stubborn love love feel bad though make cry lol',
#  'grouchy want bmar',
#  'heart break every morning drop foo pre school understand mom say quot heart break quot',
#  'feel well back hurt',
#  'im mood chocolate want miniature reeses cup',
#  "ca n't take heat 's like oven feel sick nwo",
#  'nick carter come chat minute please http fanclub backstreetboys com chat php',
#  'boredd colddd internet keep stuff',
#  "horrible nightmare last night affect sleep 'm really tire",
#  'im lonely keep company female new york',
#  'bear broadway lose st ignacius prepatory school haha',
#  'birutagme yeah really depress stuff like get',
#  'whoisariston problem tongue cheek remark lot acronym nz',
#  'greggrunberg hey say matt gon na go ballistic disappointed good ep tho mostly',
#  'ugh horrible ending sandra kantu story prayer go',
#  "danielledeleasa http twitpic com pe hate b allergic want puppy soo bad 've already think cool name",
#  'morning folk yawn amp away see horse hope twitter good behave today last night travesty',
#  'quandotcom miss mine',
#  'amandaenglund sorry hear loss many year far',
#  'nicolerichie gossip girl repeat',
#  'inyoureyes reckon',
#  'find really hard use twitter',
#  "'ve stick house two day",
#  "really sad n't really know",
#  'thousand mile',
#  "maybe one year 'll get tax return girl dream right",
#  'back work tire hell feel cold come',
#  "clarianne knot serious april th n't come soon enough",
#  "hannahsix cream eye may herpes ocular herpes different strain 's okay though",
#  'get ta repeat whole art folio cuz old one whole term work get wet',
#  "'m ready weekend already 's monday",
#  "lovebscott umm nope think im insomniac plus get flu i'lll sleepin like phuckin fish outta water minute",
#  'finland sleeping night really enough time',
#  "lunafiko ca n't wait try em prolly wait next weekend early",
#  'shiner take bed blanket',
#  "clarianne april th n't come soon enough",
#  'want cry',
#  'need go bank tomorrow go break',
#  "earthquake italy sadden 's three hour away naples family",
#  'sleeping stress week come',
#  'dragoneer yea work tp hack server player thing folk',
#  'hurt ankle go dr',
#  'raymondroman oh no manage send something trash empty without notice feel ya',
#  "lose free copy radioactive ca n't put ipod grr ca n't go buy 'nother coz come paper",
#  'make shit',
#  'photoshop hate crash',
#  'vacation make feel sick',
#  "n't go",
#  'listen murd th wonder chillen miss crazy sex life',
#  'louie shoot careful luisa',
#  "hillary 'm sure everyone ruin gift whitney serious cell easter well",
#  'beso hollywood tire',
#  "n't want wake early tomorrow damn work",
#  'finish watch movie prayer bobby break heart',
#  'syekr myki really horrible',
#  'stephenkruiser put dog today someone run',
#  'nevadawolf sorry hear dnf run tonight always risk get bad coords ftf',
#  'honey get disgruntled people write esn hit one day make bill pull top',
#  "moony ohh omg lmao 'm cry right lol kutnerrrr best",
#  'come back run take shower low stomach still hurt exercise',
#  'watch fallon mom work project school hard',
#  'min till home time count crave visit mac store close time get',
#  'stephenkruiser sorry hear take care',
#  'paulcoles hmmm greed good motivate individual good much take away others',
#  "gabbyisactive brat rub n't want mocha",
#  "kutnerrrr think still show ugh kutner kal penn 've bright star ho",
#  'redvinylgirl mom wish best luck',
#  'hate homework head hurt bad',
#  "get ebay blue item want jump bidder hour still hour go 'd good get hop",
#  'gigdiary know little depress eat much last night leftover today',
#  'well pc live room suffer fatal partion lose itunes library go doc pic',
#  'sad day manu season',
#  'stephenkruiser poor spunky sad rotti make go path know feel',
#  'im sooo sad right need hug',
#  'want step brother home im worry dont even know hope know much care',
#  'heidimontag get do watch hill love excite next episode im sad last season',
#  'ryanmwilson aww stink hug',
#  "'m tire feel like crap world feel crummy make happy usb disco mouse",
#  'dont want believe im read buu sad',
#  'wonder gamebattles',
#  'white trash v u outnumber http twitpic com jp',
#  "emitstop true n't use",
#  'spring break last one celebrate',
#  "morning bah car wo n't start wait anwb",
#  "katebornstein pretty anti memorial tattoo strict 's official ban disapprove family",
#  "balamurugan longterm member team leave month 'll miss work hope well next venture",
#  'justgelo sad know find body crazy world live child deserve ya know',
#  'wan na rock maxi dress coachella lacking fund',
#  'course baby screaming crib night first day back work let cry boooo',
#  'home miss baby busy week ahead fri chill day guy kid egg hunt sit spiral dmb sit night easter',
#  "followsavvy never find everytime click twitter thing myspace go dude 's page",
#  "stephenkruiser 's horrible sorryto hear",
#  "david henrie cant find say dtmafiaofficial doesnt exist 's jus dtmafia find n u dun seem b followin wht",
#  'think would support',
#  "augh eff sarth steal mil 's nail polish pretty",
#  "wish spring fling tour dawn amp neecee sigh g'knight",
#  "hoyts distribution nz website n't work great like need",
#  "crummyasshole n't like first movie cillian murphy hot",
#  "wish good old cartoon come back ie captain planet 's wally daria sadness",
#  'feel v good abt',
#  'get text sarah',
#  'another day centre point time early start guess train ram commuter',
#  'four game fall modern warfare halo odst brutal legend bioshock need cash',
#  "castillo ugh 's disconcert",
#  'devinthedude actually whole site finally take damn russian',
#  'tweet arent go',
#  "finish delicious breakfast last paris 'll miss milk europe tasty milk world n't drink u",
#  'ilearn great consider final week',
#  "carmonium 'm stress outttt",
#  'also shouldve bern asleep hour ago',
#  'try figure twitter thing none friend yet soo much see',
#  'ping kyle custom icon make look cool edge could less square might look bad diff background',
#  'want back la',
#  "enterbelladonna dunno use forum get frustrate 'll miss talk",
#  'lilbucknuts option',
#  "georgeruiz unfortunately one moment n't giant squid monster",
#  'thestar rage want one branch midv open',
#  'dananner aw sorry hear',
#  'change plan order mac instead time hit book',
#  'polhillian yup',
#  "nkdreamer see donnie 's tweet stats almost reply jrk",
#  "tim grainger nah n't receive stimulus yet",
#  'ikimb see ur tweet plz write bak u get havnt get one reply bak',
#  'mccainblogette awwwww try go sleep hour ago',
#  "stephenkruiser 'm sorry hear 's always sad lose close u love",
#  'cant sleep im still feelin like piece shit',
#  "stephenkruiser oh sympathy 's hard decision always hope old border collie go sleep 's hug",
#  'josephheustess well really cool part wont spoil',
#  "limbecky 'm time warp without sad",
#  "theresawhite true lol 's still slap face warm end march",
#  'hate convert movie put em itouch',
#  'gross pimple',
#  "torturedlady yea ma'naaaaaaaaaaaaaaaaaaaam marwan accent lol",
#  'one less follower tonight',
#  'unholyknight mom last night brb figure whether burn',
#  'feel like quot twitterer quot tweetdeck',
#  'wyldceltic karate tournament week',
#  "go sleep ca n't n't finish statistic homework",
#  'north carolina baby aint nothin stop nba draft',
#  "ca n't sleep",
#  "reaaly miss john mayer 's twitter fuck rude people remove n't like tweet bitchfucks",
#  'go late one mqu today',
#  'im tire work need life',
#  'leavin work foot hurt',
#  'playradioplay sad unexpected totally cry haha',
#  "superneej morning bah car wo n't start wait anwb",
#  'still homework',
#  'little sad',
#  'deepbluesealove mom amp dad get around early',
#  "'ve asleep two hour ago",
#  'stephenkruiser sorry hear dog',
#  'funny little thing make homesick criminal breakn n brownstone lawnord ci make misty',
#  'djsoulsister yeah great vid quot single sell year ago',
#  "im val 's mac iitsc clubroom still sweating",
#  "stephenkruiser awww sad 'm sorry",
#  'updatingffe give nothing good twenty minute',
#  'hot compress rily workng pull muscle gng bed good night',
#  'invite quot healthy din quot session ashok hotel today exec chef r chopra damn workload skip',
#  "stephenkruiser 'm sorry hear dog wish happy day come",
#  "hellivina miss 'em",
#  'misstoriblack cool tweet apps razr',
#  "'m bed get ta wake hella early tomorrow morning",
#  "still procrastinate hate organize clothe 's much",
#  "play new mobbler v add great new feature wo n't play music e like v",
#  "latroneb oh 's one bestie miss",
#  "esuriospiritus time come back flawda double date seriously 'm sorry hear",
#  "'m way late work client fb",
#  'blegghhhh go work',
#  'back work john muir dr http loopt u koqabg',
#  'dachesterfrench email yesterday u never respond',
#  "'s go long year 's fan",
#  'get do watch new house episode definitely one sad episode ever',
#  "man tax suck 'm horrified something wrong turbotax decide keep around lot stuff turn",
#  'sleep time tomorrow gon na suck',
#  "wtf kutner oh 'm pissed house mean really wtf",
#  'amberpacific know dont know say',
#  'cash rule everything around',
#  'pick oat market eat breakfast boy adamgoldston time work usc late night',
#  'feel sick much icecream',
#  "faithgg computer n't shockwave blah account yet",
#  'rubyrose awww wish could go sydney',
#  'luxuryprgal hahaha suriously feel like everyone know show joke except lc',
#  "ca n't spell today totally suck",
#  'vaccinated chicken pox vaccinate yr old confuse damn thing',
#  'school least last day',
#  "yawwwn get ta get early tomorrow 's ready weekend",
#  'miss home calve season sad black one die morning wish bottle calf',
#  'stephenkruiser sorry loss brother dog sam sick w cushing disease',
#  'back work get spend next hour alone dispatch room',
#  "'s new kind starburst favereds sound fab bc cherry strawberry fav red 's add watermellon yucky",
#  'well much productive day angel',
#  'andreabakes oh gee insomnia suck try melatonin',
#  'vivekg good hear support netbeans netbeans know',
#  'heidimontag wish would get time rest world unfornately cairo wait mtva play',
#  'heartbroken little sandra prayer family',
#  "hadtobeyou 'm word 's 'll finish tomorrow maybe",
#  'shortiethug come ur background cover screen mine corner',
#  'write exactly three line dialogue tonight give',
#  "ashman complaint facebook 've change much 's confuse",
#  'slice finger',
#  'go thru town traffic bypass stink',
#  "ugh ca n't sleep wish good cuddle make as",
#  "hate software update download update without tell never know 's download",
#  'go ihop great diet least kung foo pancake time rachel',
#  "internet hat night s'pose",
#  "contactabe 'm jealous miss opening day year",
#  "'s cruel wait review come far look like star trek best film year",
#  'debate shower sleep little late tomorrow',
#  'stress always culminate physical pain',
#  'need sleep cant',
#  'little pinky finger hurt much',
#  "sarahsaturday 'm sorry gift card run suck",
#  'home spring break one home tho',
#  "access oneindia mobi google phone android n't support indic language",
#  "school take life much n't get sleep anymore still school work well",
#  "mtsiaklides aw wish could ca n't really speak yia yia n't speak english",
#  'winggato free comp lol',
#  'get ready clean house top bottom',
#  'cry friend move away tomorrow',
#  "swiftkaratechop stop nomnoms n't share night people",
#  'think get cold catch daddy oh trip would ruin',
#  'moony yeah bcoz kal penn visit lecturer somewhere n cant show anymore im gon na miss',
#  "procrastination start early quarter n't want reaaaaad write paper",
#  "apparently 's degress pm washington state miss winter already",
#  'bored homee',
#  "massage great spill coke desk lame watch simpson 've finish hill dvd",
#  "nick carter wait fanclub chat even tough 're favorite",
#  'mild leave inner ear infection get irritating quot block quot feel since sunday',
#  'janebodehouse hey nope cuteness hoytfortenberry away awhile',
#  "'s tuesday",
#  "haha even yo n't know thang twitter haha",
#  'someone alarm clock phone wake still get headache yesterday night',
#  'kalichosich awww poor puppy ok',
#  'might break eat buffalo wing tomorrow',
#  "sittin w kayla really really reallly dis like brother n't know stop 'm wait day one",
#  'feed bokkie many birthday treat sicko',
#  "'s kinda bum agency tell n't 'look ' go lady please help create 'look '",
#  'work laptop officially dead happy',
#  "goodness 's freeze",
#  'heidimontag put listen mom',
#  "stucked paris ca n't even travel france work",
#  "joannafbeckett n't think 's one close last time check close one mile away",
#  'aaaaand back literature review least friendly cup coffee keep company',
#  "worry wo n't get even though pay buttload tax last year",
#  'okay still school',
#  'phoneless sleep',
#  'reek alcohol dentist morning drink put tshirt realise huge stain dentist look disgust',
#  'really cold',
#  'cant sleep want dream',
#  "ca n't sleep hate night try go bed early stay awake hour poo",
#  'rootbeersoup yeah bad people like certain burrito eat man exist',
#  "cronotriggers 's sad",
#  'find mum adopt auntie twitter check mum tessm awesome auntie tania',
#  'sleep wide awake get ta go work late boy go crappy day',
#  'struggle eam law',
#  "ca n't sleep like http twitpic com ty",
#  "bout start poor linny could n't keep eye open tire work tomorrow morning night ilovefatsusan",
#  "year old year old drive around twist n't want like",
#  'well suck',
#  'place day help get pack painting clean much appreciate oh rip wall',
#  'opening partially freeze beer beer toaster oven counter kitchen smell like run speakeasy',
#  'stewiebrittany dont even know ride',
#  'monasmith sadly yes think need counciling',
#  "make ready school n't feel like go two test",
#  "smugness go train also fail turn 'm head victoria follow unpleasant tube ride city",
#  'anybody know ipod go',
#  "aww earthquake italy make sad saw pic news 's terrible",
#  "lilibat never able afford get 'd much rather go extraction continue deal",
#  'pet care people try run others business send suspicious e mail fishing info',
#  "kameelahwrites lt codez 've mia tho",
#  'reannaremick doesnt work cell go sleep p',
#  "'s go nice tomorrow rain come back nice weather birthday",
#  'taliasunset rock band hard expert',
#  'beachbassbone roomie home day scratch door comforter goto large laundromat machine',
#  'one hard thing schedule one chat end day usually',
#  "kill character one favorite show 'm upset",
#  'jealous friend get see new star trek film austin tonight',
#  'listen q get really bad headache drivin lesson ten min lucky wana sleeep',
#  'steve buscemi shut hungry britain home boring suckassy breakfast world miss dennys',
#  'good morning everybody pkoi fais pa beau bon coffee time',
#  'work',
#  'essay time',
#  'chauncey hey u talk mom r home yet hope r ok wish come home easter',
#  'endearingevania sure wish could go guy tmrw per usual school interfere',
#  "widyatarina say kal penn 's leave house noooooo awww totally miss tonight",
#  'lose loyal',
#  'play another hand bad lose half stack',
#  "'s pm early day looooooong night work",
#  "yaykimo 's sad 's last season wan na see spencer call lauren",
#  'im do edit quot phipstape quot back crack brew see get tree though',
#  "rj n't know half mean",
#  'homework homework homework',
#  'work heart today double weight station result stiff pull muscle ouch',
#  'melamachinko feel bad unfollowing',
#  'tire god hate new job two day',
#  'sad kutner kill fav show house',
#  'happy coach stringer hof c finish term paper',
#  "feel like shit way want spend birthday 's eve",
#  'far sit put together check update make',
#  'lot mind need make money idea nowhere hire',
#  'emiliexclarkex miss',
#  "stephenkruiser 'm sorry hear dog",
#  'much internet plague',
#  'miss ex soo much',
#  'sodding http twitpic com',
#  "oh think pirate bay trial verdict today apparently 's day",
#  'featherinair call back',
#  'study hall log immediately http plurk com p mzxbg',
#  'tire im cry reason im try get hour half tonight half get last night',
#  'totally like four girl option none seem viable',
#  'far veiws sit put together check update make',
#  "listen bjork 's full love cry",
#  'omg hill love money aww think becky buckwild go',
#  'crave tantan nabe http plurk com p mzxcs',
#  "c'mon sean man",
#  'watch quot league quot make miss mint chocolate ice cream cone grand fuck',
#  "lose phone maybe grass long hope n't rain",
#  "tomatosalsa hope n't refer say hello new stalker lol",
#  'brettyboo u sleeping ur gon na night ur bike ride',
#  'slessard wan na listen master',
#  "sephystryx 've look good stuff write also load uni work",
#  'feel unloved drop tweeter',
#  "london day thursday 's gon na raining oh fab wo n't see much london eye still robbie wo n't care bless",
#  'completely wipe reload lose bbm contact go bed sad',
#  "mykele sayyyy whaaaa n't invite",
#  "n't sleep bad consider workshop start today beginning sore throat though",
#  'astewart oh gosh make emotional haha idk dont want get old',
#  "'re go post story manually due twitterfeed problem 's 've quiet lately",
#  "n't like lukewarm shower",
#  'linuxfoundation contact need freelance work linux com throughout never get one',
#  "skylineking connor 's febi really really mad",
#  'need help want buy macbook pro still inlove old powerbook',
#  'michaeltao man america borez anyway lol realize send msg idea flash',
#  "hellivina ihopness g'knight lovely lady 'm sleepy",
#  'anybody know get electrolyte back order vitamin work feel sick',
#  "sudam yes someone n't read post properly",
#  'almost italian homework weeeeee understand',
#  'turn light time get ip',
#  'therealnph twitter hat u',
#  "hate fact 'm genuinely excite last tweet",
#  "celesteclara ca n't sleep either",
#  "theblondetheory italy earthquake 's sad news day",
#  'champagnemanoir rain today garden really need quite bad',
#  'yawn yawn yawn minute bed',
#  'majesticflame ouch sound sucky',
#  "bengottlieb great idea itunes promo cod n't work uk itunes store though",
#  'mattycus cry',
#  'rumlover empty rum barrel sad rum barrel shake head horror horror',
#  'sleepless night',
#  'billybush admit fake',
#  'batmannn love chutney',
#  'get highly bored today scan page daddy',
#  'misterphipps cook risotto without',
#  'keeeerrrrriiiiii really nothing good post thing wonderfullll say alot',
#  'yay baseball season boo yankee lose first game',
#  'lose suck work today',
#  'omg exam kill could know difference haif circle hemisphere lt gt',
#  'bed suddenly feel wish w goodnight twitterfam',
#  "rachelcmrn n't like goodnights",
#  "greaaat lappy wo n't turn wtffffff",
#  "rkm stick traffic journey traffic free morning 's help",
#  'lookin like nighter hate',
#  "vernonhamilton 're strange",
#  'debbugging old vb code day could start good',
#  'toddlington quarter percent babe darn',
#  "come cold bad allergy either way 'm miserable",
#  "ca n't believe cutner dead house sad day santa rosa ca http loopt u orpl",
#  'damnit really dig season reaper http www tv com story html ref story id amp ref type amp ref name story',
#  'gah comcast double cable internet bill w tell u quit anyone suggest affordable company bay area',
#  "another early morn duchess although n't manage cross leg time",
#  'alexbigman leave without say hi',
#  "l want ca n't sleep",
#  "tracydowds xbox show three red light mean 's dead need fix month microsoft hq",
#  'king size bed nice sad lonely hubby puppy kitty whole conferenceing thing',
#  'im boredd gah wish could sleep get ive toooo muchh cooooffffeeeeeeeee bahaha',
#  "whyinthehell may butt 'm do nosey sorry conversation interest",
#  'smokey robinson fell list offend',
#  'week till sister home miss call bad feel world',
#  'gon na try get sleep hotel room',
#  "chimpytwit brilliant idea bring much think 'll spend amp 'll swap bring brolly",
#  "simonekali get autograph shout record though computer dead ca n't listen",
#  'rt kimkardashian khloe get fire apprentice',
#  'biology class lip hurt',
#  'sorry next tweet',
#  'grr go school today',
#  'jennlopez get hd tivo get set tonight order get channel',
#  'mouthsex ask everyone yesterday single tweet back',
#  'adame ruddy money like still wait oh surprise state hmmm seriously',
#  'kal penn sad kutner favorite new team',
#  "marcusmims wow n't get quot hello quot u suck",
#  'bedtime school tomorrow still book break suck',
#  'seat help baby paper well force seat im sleepy',
#  'synching contact old mobile iphone import work well',
#  "ca n't concentrate",
#  "'ve spend hour enter bureaucratic nonsense march waste time",
#  'nw confuse ever',
#  'feel well stupid migraine make tummy upset whole body ache shoot',
#  'read buyology bedtime great premise turn quot ok quot book lot info already know',
#  'home really wana sleep due waste free line town assignment finish',
#  'hellobebe also send update plurk upload photo twitter didnt see update plurk zero',
#  'omg quot reader quot make',
#  "cloudpimps d'oh least 're get decent exchange rate moment sterling still get flog",
#  'try download tweetdeck wont download',
#  "'s inch snow grind count 'm worry poor flower",
#  "dweeman n't happy camper",
#  "dkoenigs thanks man 'm grateful feel unworthy attention though 'm",
#  "wolfe miss u 'm totally comin back tho lastnight sooooooo much fun",
#  "sniffinglue ohhh love p 'm sad n't get hang",
#  'somehow still end place',
#  'kisluvkis oh sad poor boy',
#  ...]
